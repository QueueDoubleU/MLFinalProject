# %%
# !pip3 install convokit
# !python3 -m spacy download en_core_web_sm

import pandas as pd
import nltk

from convokit import Corpus, download
# Out:
# Requirement already satisfied: convokit in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (2.5.3)
# Requirement already satisfied: scipy>=1.1.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (1.9.0)
# Requirement already satisfied: msgpack-numpy>=0.4.3.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (0.4.8)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (3.5.3)
# Requirement already satisfied: joblib>=0.13.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (1.1.0)
# Requirement already satisfied: clean-text>=0.1.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (0.6.0)
# Requirement already satisfied: unidecode>=1.1.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (1.3.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (1.1.2)
# Requirement already satisfied: spacy>=2.3.5 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (3.5.2)
# Requirement already satisfied: dill>=0.2.9 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (0.3.6)
# Requirement already satisfied: nltk>=3.4 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (3.8.1)
# Requirement already satisfied: pandas>=0.23.4 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from convokit) (1.4.3)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from clean-text>=0.1.1->convokit) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from clean-text>=0.1.1->convokit) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (4.37.1)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.0.5)
# Requirement already satisfied: tqdm in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from nltk>=3.4->convokit) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from nltk>=3.4->convokit) (2023.3.23)
# Requirement already satisfied: click in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from nltk>=3.4->convokit) (8.1.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from pandas>=0.23.4->convokit) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from scikit-learn>=0.20.0->convokit) (3.1.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (1.0.4)
# Requirement already satisfied: jinja2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (8.1.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (3.0.8)
# Requirement already satisfied: setuptools in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (65.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (1.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (2.28.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (1.10.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (2.4.6)
# Requirement already satisfied: wcwidth>=0.2.5 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from ftfy<7.0,>=6.0->clean-text>=0.1.1->convokit) (0.2.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=2.3.5->convokit) (4.5.0)
# Requirement already satisfied: six>=1.5 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->convokit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3.5->convokit) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3.5->convokit) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from jinja2->spacy>=2.3.5->convokit) (2.1.1)
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 41.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: setuptools in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (65.3.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: numpy>=1.15.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.23.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: jinja2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/quinn/opt/anaconda3/envs/pp275/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
corpus = Corpus(filename=download("supreme-corpus"))
# Out:
# Dataset already exists at /Users/quinn/.convokit/downloads/supreme-corpus

# %%
utt_ids = corpus.get_utterance_ids()
transcript = corpus.get_utterance(utt_ids[100])

# %%
# use basic dataframe cause why not
df = corpus.get_conversations_dataframe()

df.head()
# Out:
#       vectors meta.case_id                                     meta.advocates  \
# id
# 13127      []      1955_71  {'harry_f_murphy': {'side': 1, 'role': 'inferr...
# 12997      []     1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 13024      []     1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 13015      []     1955_351  {'harry_d_graham': {'side': 3, 'role': 'inferr...
# 13016      []      1955_38  {'robert_n_gorman': {'side': 3, 'role': 'infer...
#
#       meta.win_side                                    meta.votes_side
# id
# 13127             0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...
# 12997             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 13024             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 13015             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 13016             0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...

# %%
# get_transcript(df.id[0])
df['convo_id'] = df.index

# %%
df = df.reset_index().drop(['id'], axis=1)

# %%
df['term_year'] = [case_id.split('_')[0] for case_id in df['meta.case_id']]
df['docket_id'] = [case_id.split('_')[1] for case_id in df['meta.case_id']]
df.head(-5)
# Out:
#      vectors  meta.case_id                                     meta.advocates  \
# 0         []       1955_71  {'harry_f_murphy': {'side': 1, 'role': 'inferr...
# 1         []      1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 2         []      1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 3         []      1955_351  {'harry_d_graham': {'side': 3, 'role': 'inferr...
# 4         []       1955_38  {'robert_n_gorman': {'side': 3, 'role': 'infer...
# ...      ...           ...                                                ...
# 7807      []     2019_19-7  {'kannon_k_shanmugam': {'side': 1, 'role': 'fo...
# 7808      []  2019_18-6662  {'richard_m_summa': {'side': 1, 'role': 'for t...
# 7809      []  2019_17-1712  {'peter_k_stris': {'side': 1, 'role': 'for the...
# 7810      []   2019_18-916  {'adam_h_charnes': {'side': 1, 'role': 'for th...
# 7811      []   2019_19-715  {'patrick_strawbridge': {'side': 1, 'role': 'f...
#
#      meta.win_side                                    meta.votes_side  \
# 0                0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...
# 1                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 2                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 3                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 4                0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...
# ...            ...                                                ...
# 7807             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
# 7808             0  {'j__john_g_roberts_jr': 0, 'j__clarence_thoma...
# 7809             0  {'j__john_g_roberts_jr': 0, 'j__clarence_thoma...
# 7810             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
# 7811             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
#
#      convo_id term_year docket_id
# 0       13127      1955        71
# 1       12997      1955       410
# 2       13024      1955       410
# 3       13015      1955       351
# 4       13016      1955        38
# ...       ...       ...       ...
# 7807    24977      2019      19-7
# 7808    24968      2019   18-6662
# 7809    24959      2019   17-1712
# 7810    24954      2019    18-916
# 7811    25000      2019    19-715
#
# [7812 rows x 8 columns]

# %%
def get_transcript(convo_id, remove_return=False):

  # pull conversation object
  convo = corpus.get_conversation(convo_id)

  # from conversation object, create list of utterance (i.e. the text bits) ids
  convo_utts = list(convo.iter_utterances())
  
  # combine text data from all utterances 
  if remove_return:
    convo_transcript = [utt.text.replace('\n', ' ') for utt in convo_utts]
  else:
    convo_transcript = [utt.text for utt in convo_utts]

  # join elements of list 
  convo_transcript = ''.join(convo_transcript)
  
  return convo_transcript

# %%
get_transcript(df.convo_id[0])
# Out:
# 'Number 71, Lonnie Affronti versus United States of America.\nMr. Murphy.May it please the Court.\nWe are here by writ of certiorari to the Eighth Circuit.\nThere is one question to be decided in this case, decided carefully.\nUpon sentence to consecutive sentences or terms by a District Court.\nThe defending pattern started the service of a first sentence.\nThus, the District Court thereafter have jurisdiction to suspend the execution of the remaining sentences and place the defendant on probation.Consecutive sentences.Consecutive sentences.\nIn this case, the defendant, Affronti, was indicted in 1932 by a grand jury in the Western District of Missouri.\nCharged in an indictment in ten counts with the illegal sale of narcotics.\nI\'ve mentioned the dates because they, if not of importance, will be of interest.\nIn 1944, the defendant was brought in to the District Court at Kansas City on a writ of habeas corpus ad prosequendum from the Missouri State Penitentiary where he was in the service of a sentence for second degree murder.\nThe District Judge on that -- at that time was Judge Caskie Collet.\nUpon trial before a jury, the defendant was acquitted on the first of the ten counts, found guilty on the remaining nine and sentence was pronounced disclosed.\nOn all nine counts of the -- the indictment, he was sentenced to serve five years which was the maximum sentence under the statute that had been violated.Sentences two, three, four and five were pronounced to run consecutively.\nThe remaining five sentences, sentence was suspended and the defendant was to be placed upon probation for a period of 25 years.\nThe judgment further provided that the sentence on the second count would be to commence at the time he was released from authorities in Missouri State.\nIn 1949, after his release from the Missouri State Penitentiary, he was delivered to the United States Marshal for the service of the first five years of the second count of the indictment.\nIn 1953, four years later --Was the aggregate prison sentence was 20 or 25 years?Twenty years.Twenty years.Twenty years, four -- four counts of five years.\nBut the computation is a question whether he had yet started the service as -- as second of his third five years, but in 1943, at which time Judge Duncan had succeeded Judge Collet as the District Judge in that division, Judge Collet having been promoted to the Eighth Circuit bench.\nA motion was filed on his behalf requesting that the remaining sentences yet to be served, either the third, fourth, and fifth counts or the fourth and fifth, that the execution of the sentence as yet to be served be suspended and be placed on probation.\nNow, in -- two months prior to the filing of the motion on behalf of the petitioner in the District Court, Judge Reeves, another division of the Western District had ruled in the case of Phillips versus the United States for the facts as far as sentences are concerned, were identical with the facts in this case, and that Phillips, the defendant, was in the service of the first of three consecutive terms.\nThat the Court was without jurisdiction to entertain such a motion as the term had passed and the 60 days had -- had passed when he had -- after he had been first sentenced.\nPending the appeal of the Phillips case, Judge Duncan held in abeyance of ruling on the Affronti case.\nOn appeal to the United States Court of Appeals for the Eighth Circuit, the Phillips decision was affirmed.\nOn that bench, sitting as a member of the Court of Appeals, was Judge Collet.\nAnd in a dissenting opinion, he held that a District Court in his opinion had a right to retain jurisdiction over sentences yet to be served.\nAfter the Phillips case was passed, the time had passed, no application was made to this Court for certiorari, although the Court of Appeals had recommended that he\'d be permitted to apply without the payment of cost.\nThe Court -- appeal was taken in the Affronti case to the same court.\nAnd again, ...

# %%
import numpy as np

# %%
df.head()
# Out:
#   vectors meta.case_id                                     meta.advocates  \
# 0      []      1955_71  {'harry_f_murphy': {'side': 1, 'role': 'inferr...
# 1      []     1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 2      []     1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 3      []     1955_351  {'harry_d_graham': {'side': 3, 'role': 'inferr...
# 4      []      1955_38  {'robert_n_gorman': {'side': 3, 'role': 'infer...
#
#   meta.win_side                                    meta.votes_side convo_id  \
# 0             0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...    13127
# 1             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...    12997
# 2             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...    13024
# 3             1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...    13015
# 4             0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...    13016
#
#    year term_year docket_id  case_transcript
# 0  1955      1955        71              NaN
# 1  1955      1955       410              NaN
# 2  1955      1955       410              NaN
# 3  1955      1955       351              NaN
# 4  1955      1955        38              NaN

# %%
martin_quinn = pd.read_csv('MartinQuinnScores.csv')

# %%
martin_quinn
# Out:
#     term      med  med_sd    min    max       justice  just_pr  CEHughes2  \
# 0   1955    0.559   0.484 -4.166  1.348  FFrankfurter    0.774        NaN
# 1   1956  0.162.5   0.510 -4.670  1.322       TCClark    0.984        NaN
# 2   1957     0.58   0.545 -5.082  1.386       TCClark    0.951        NaN
# 3   1958    0.643   0.578 -5.457  1.643       TCClark    0.492        NaN
# 4   1959    0.335   0.621 -5.759  1.846       TCClark    0.870        NaN
# ..   ...      ...     ...    ...    ...           ...      ...        ...
# 62  2017    0.298   0.501 -3.720  3.131     AMKennedy    0.520        NaN
# 63  2018    0.402   0.535 -3.852  3.166     JGRoberts    0.716        NaN
# 64  2019    0.355   0.571 -3.969  3.158     JGRoberts    0.784        NaN
# 65  2020    0.741   0.630 -4.070  3.050   BMKavanaugh    0.476        NaN
# 66  2021    0.827   0.675 -4.137  3.133   BMKavanaugh    0.436        NaN
#
#     JCMcReynolds  LDBrandeis  ...  CThomas  RBGinsburg  SGBreyer  JGRoberts  \
# 0            NaN         NaN  ...      NaN         NaN       NaN        NaN
# 1            NaN         NaN  ...      NaN         NaN       NaN        NaN
# 2            NaN         NaN  ...      NaN         NaN       NaN        NaN
# 3            NaN         NaN  ...      NaN         NaN       NaN        NaN
# 4            NaN         NaN  ...      NaN         NaN       NaN        NaN
# ..           ...         ...  ...      ...         ...       ...        ...
# 62           NaN         NaN  ...      0.0         0.0       0.0     0.4758
# 63           NaN         NaN  ...      0.0         0.0       0.0     0.7161
# 64           NaN         NaN  ...      0.0         0.0       0.0     0.7836
# 65           NaN         NaN  ...      0.0         NaN       0.0     0.3522
# 66           NaN         NaN  ...      0.0         NaN       0.0     0.3130
#
#     SAAlito  SSotomayor  EKagan  NMGorsuch  BMKavanaugh  ACBarrett
# 0       NaN         NaN     NaN        NaN          NaN        NaN
# 1       NaN         NaN     NaN        NaN          NaN        NaN
# 2       NaN         NaN     NaN        NaN          NaN        NaN
# 3       NaN         NaN     NaN        NaN          NaN        NaN
# 4       NaN         NaN     NaN        NaN          NaN        NaN
# ..      ...         ...     ...        ...          ...        ...
# 62   0.0000         0.0     0.0     0.0037          NaN        NaN
# 63   0.0000         0.0     0.0     0.0249       0.2590        NaN
# 64   0.0000         0.0     0.0     0.0183       0.1981        NaN
# 65   0.0000         0.0     0.0     0.0947       0.4757     0.0774
# 66   0.0001         0.0     0.0     0.2007       0.4355     0.0507
#
# [67 rows x 55 columns]

# %%
df = df.rename(columns={'term_year': 'term'})

df.term = df.term.astype('int64')
df.head()

df_full = df.merge(martin_quinn[['term', 'med']], on='term')
df_full
# Out:
#      vectors  meta.case_id                                     meta.advocates  \
# 0         []       1955_71  {'harry_f_murphy': {'side': 1, 'role': 'inferr...
# 1         []      1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 2         []      1955_410  {'howard_c_westwood': {'side': 1, 'role': 'inf...
# 3         []      1955_351  {'harry_d_graham': {'side': 3, 'role': 'inferr...
# 4         []       1955_38  {'robert_n_gorman': {'side': 3, 'role': 'infer...
# ...      ...           ...                                                ...
# 7812      []   2019_19-635  {'jay_alan_sekulow': {'side': 1, 'role': 'for ...
# 7813      []    2019_19-46  {'erica_l_ross': {'side': 1, 'role': 'Assistan...
# 7814      []   2019_19-177  {'christopher_g_michel': {'side': 1, 'role': '...
# 7815      []  2019_18-1584  {'anthony_a_yang': {'side': 1, 'role': 'for th...
# 7816      []    2019_19-67  {'eric_j_feigin': {'side': 1, 'role': 'for the...
#
#      meta.win_side                                    meta.votes_side  \
# 0                0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...
# 1                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 2                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 3                1  {'j__john_m_harlan2': 1, 'j__hugo_l_black': 1,...
# 4                0  {'j__john_m_harlan2': 0, 'j__hugo_l_black': 0,...
# ...            ...                                                ...
# 7812             0  {'j__john_g_roberts_jr': 0, 'j__clarence_thoma...
# 7813             0  {'j__john_g_roberts_jr': 0, 'j__clarence_thoma...
# 7814             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
# 7815             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
# 7816             1  {'j__john_g_roberts_jr': 1, 'j__clarence_thoma...
#
#      convo_id  term docket_id    med
# 0       13127  1955        71  0.559
# 1       12997  1955       410  0.559
# 2       13024  1955       410  0.559
# 3       13015  1955       351  0.559
# 4       13016  1955        38  0.559
# ...       ...   ...       ...    ...
# 7812    24998  2019    19-635  0.355
# 7813    24978  2019     19-46  0.355
# 7814    24979  2019    19-177  0.355
# 7815    24972  2019   18-1584  0.355
# 7816    24969  2019     19-67  0.355
#
# [7817 rows x 9 columns]

# %%
df_full = df_full.rename(columns={'meta.advocates': 'advocates', 
                                  'meta.votes_side': 'votes_side',
                                  'meta.win_side': 'win_side',
                                  'meta.case_id': 'case_id',
                                  'med': 'mq_score'})

df_full.to_csv('Outcomes_NoTranscript.csv')
